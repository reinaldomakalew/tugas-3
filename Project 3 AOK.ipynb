# %% [markdown]
# # EXPLORATORY DATA ANALYSIS
# ### Exploratory Data Analysis memungkinkan analisis data yang digunakan mulai dari distribusi, frekuensi, korelasi dan lainya

# %%
# masukkan library yang akan kita gunakan
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# melakukan pembacaan data pada dataset dalam format
data = pd.read_excel('DATAAOK.xlsx')

# %% [markdown]
# # DATA SURVEY KELOMPOK 3

# %% [markdown]
# ## Info Data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501 entries, 0 to 500
# Data columns (total 10 columns):
#  #   Column                                                                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                                                                         --------------  -----
#  0   Unnamed: 0                                                                                                                                     501 non-null    object
#  1   Apakah hardisk tipe ssd memiliki performa kerja lebih baik dari hdd dalam hal kecepatan mengakses data                                         501 non-null    int64
#  2   Apakah pengguna setuju bahwa dual core (multi core )pada prosessor lebih cenderung mempercepat kinerja system computer dibandingkan quad core  501 non-null    int64
# ...

# %%
data.dtypes
# Out:
# Unnamed: 0                                                                                                                                       object
# Apakah hardisk tipe ssd memiliki performa kerja lebih baik dari hdd dalam hal kecepatan mengakses data                                            int64
# Apakah pengguna setuju bahwa dual core (multi core )pada prosessor lebih cenderung mempercepat kinerja system computer dibandingkan quad core     int64
# Apakah dengan menggunakan VGA NVIDIA GeForce saat akan melakukan aktivitas gaming tidak ada lag                                                   int64
# Agar dapat support dengan aplikasi yang bersifat multi core harus menggunakan memori yang besar                                                   int64
# Saat melakukan aktivitas multitasking pada komputer  dengan menggunakan processor multi core tidak akan menjadi masalah                           int64
# ...

# %% [markdown]
# # Data Responden

# %%
data
# Out:
#         Unnamed: 0  \
# 0      Responden 1
# 1      Responden 2
# 2      Responden 3
# 3      Responden 4
# 4      Responden 5
# ..             ...
# 496  Responden 497
# 497  Responden 498
# 498  Responden 499
# 499  Responden 500
# 500  Responden 501
#
#      Apakah hardisk tipe ssd memiliki performa kerja lebih baik dari hdd dalam hal kecepatan mengakses data  \
# 0                                                    4
# 1                                                    5
# 2                                                    4
# 3                                                    4
# 4                                                    5
# ..                                                 ...
# 496                                                  4
# 497                                                  3
# 498                                                  4
# 499                                                  4
# 500                                                  4
#
# ...

# %%
data.head(6)
# Out:
#     Unnamed: 0  \
# 0  Responden 1
# 1  Responden 2
# 2  Responden 3
# 3  Responden 4
# 4  Responden 5
# 5  Responden 6
#
#    Apakah hardisk tipe ssd memiliki performa kerja lebih baik dari hdd dalam hal kecepatan mengakses data  \
# 0                                                  4
# 1                                                  5
# 2                                                  4
# 3                                                  4
# 4                                                  5
# 5                                                  4
#
#    Apakah pengguna setuju bahwa dual core (multi core )pada prosessor lebih cenderung mempercepat kinerja system computer dibandingkan quad core  \
# 0                                                  4
# 1                                                  4
# 2                                                  3
# 3                                                  4
# 4                                                  4
# ...

# %%
data.tail()
# Out:
#         Unnamed: 0  \
# 496  Responden 497
# 497  Responden 498
# 498  Responden 499
# 499  Responden 500
# 500  Responden 501
#
#      Apakah hardisk tipe ssd memiliki performa kerja lebih baik dari hdd dalam hal kecepatan mengakses data  \
# 496                                                  4
# 497                                                  3
# 498                                                  4
# 499                                                  4
# 500                                                  4
#
#      Apakah pengguna setuju bahwa dual core (multi core )pada prosessor lebih cenderung mempercepat kinerja system computer dibandingkan quad core  \
# 496                                                  4
# 497                                                  4
# 498                                                  4
# 499                                                  4
# 500                                                  4
#
# ...

# %% [markdown]
# # Dimensi Data

# %%
data.shape
# Out:
# (501, 10)

# %% [markdown]
# # Statistik Setiap Features

# %%
data.describe()
# Out:
#        Apakah hardisk tipe ssd memiliki performa kerja lebih baik dari hdd dalam hal kecepatan mengakses data  \
# count                                         501.000000
# mean                                            4.003992
# std                                             0.654205
# min                                             2.000000
# 25%                                             4.000000
# 50%                                             4.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Apakah pengguna setuju bahwa dual core (multi core )pada prosessor lebih cenderung mempercepat kinerja system computer dibandingkan quad core  \
# count                                         501.000000
# mean                                            3.608782
# std                                             0.960543
# min                                             1.000000
# ...

# %% [markdown]
# # Correlations

# %%
correlations = data.corr(method ='kendall')
correlations
# Out:
#                                                     Apakah hardisk tipe ssd memiliki performa kerja lebih baik dari hdd dalam hal kecepatan mengakses data  \
# Apakah hardisk tipe ssd memiliki performa kerja...                                           1.000000
# Apakah pengguna setuju bahwa dual core (multi c...                                           0.103846
# Apakah dengan menggunakan VGA NVIDIA GeForce sa...                                           0.233703
# Agar dapat support dengan aplikasi yang bersifa...                                           0.063426
# Saat melakukan aktivitas multitasking pada komp...                                           0.188132
# Apakah pengguna bisa membedakan antara hardware...                                           0.134263
# Menurut pengalaman pengguna, Apakah tempat serv...                                           0.056069
# Apakah dengan media penyimpanan yang lebih besa...                                           0.030897
# ...

# %% [markdown]
# # Correlations Map

# %% [markdown]
# #### Higher Correlations are Brighter

# %%
f, ax = plt.subplots(figsize=(25,30))
sns.heatmap(correlations, annot=True, fmt='.3f', ax=ax)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
